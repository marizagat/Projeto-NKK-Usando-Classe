# %% [markdown]
# #

# %%
from Investidor import Investidor #importando a classe Investidor

#criando um vetor de objetos do tipo Investidor, sem o perfil
investidores = [Investidor(45926320819, (5800., 4000., 1200., 200.)),
Investidor(52559670741, (5700., 4400., 1500., 400.)),
Investidor(59016004832, (5400., 3900., 1300., 400.)),
Investidor(66175672425, (5100., 3500., 1400., 300.)),
Investidor(53330429526, (5700., 3800., 1700., 300.)),
Investidor(43765563403, (5100., 3800., 1500., 300.)),
Investidor(68020822591, (5400., 3400., 1700., 200.)),
Investidor(53939481689, (5100., 3700., 1500., 400.)),
Investidor(47014057561, (4600., 3600., 1000., 200.)),
Investidor(57183542047, (5100., 3300., 1700., 500.)),

Investidor(68518284363, (5000., 2000., 3500., 1000.)),
Investidor(65806049885, (5900., 3000., 4200., 1500.)),
Investidor(54128073086, (6000., 2200., 4000., 1000.)),
Investidor(41306785494, (6100., 2900., 4700., 1400.)),
Investidor(65234831039, (5600., 2900., 3600., 1300.)),
Investidor(50964498067, (6700., 3100., 4400., 1400.)),
Investidor(50810951429, (5600., 3000., 4500., 1500.)),
Investidor(48765044397, (5800., 2700., 4100., 1000.)),
Investidor(41960083761, (6200., 2200., 4500., 1500.)),
Investidor(76657763082, (5600., 2500., 3900., 1100.)),

Investidor(64726487742, (6500., 3200., 5100., 2000.)),
Investidor(75746566283, (6400., 2700., 5300., 1900.)),
Investidor(78576734793, (6800., 3000., 5500., 2100.)),
Investidor(56440141847, (5700., 2500., 5000., 2000.)),
Investidor(66827423000, (5800., 2800., 5100., 2400.)),
Investidor(45267873396, (6400., 3200., 5300., 2300.)),
Investidor(46387191493, (6500., 3000., 5500., 1800.)),
Investidor(54273611732, (7700., 3800., 6700., 2200.)),
Investidor(75135392881, (7700., 2600., 6900., 2300.)),
Investidor(64703873108, (6000., 2200., 5000., 1500.))]
           
#classificando o perfil
for i in investidores:
    i.identificar_perfil()

#printando o resultado
for i in investidores:
    print (i)
# Out:
# CPF: 45926320819
# Carteira de investimentos: (5800.0, 4000.0, 1200.0, 200.0)
# Perfil: Conservador
#
#
# CPF: 52559670741
# Carteira de investimentos: (5700.0, 4400.0, 1500.0, 400.0)
# Perfil: Conservador
#
#
# CPF: 59016004832
# Carteira de investimentos: (5400.0, 3900.0, 1300.0, 400.0)
# Perfil: Conservador
#
#
# CPF: 66175672425
# Carteira de investimentos: (5100.0, 3500.0, 1400.0, 300.0)
# Perfil: Conservador
#
#
# CPF: 53330429526
# Carteira de investimentos: (5700.0, 3800.0, 1700.0, 300.0)
# Perfil: Conservador
#
#
# CPF: 43765563403
# Carteira de investimentos: (5100.0, 3800.0, 1500.0, 300.0)
# Perfil: Conservador
#
#
# CPF: 68020822591
# Carteira de investimentos: (5400.0, 3400.0, 1700.0, 200.0)
# Perfil: Conservador
#
#
# CPF: 53939481689
# Carteira de investimentos: (5100.0, 3700.0, 1500.0, 400.0)
# Perfil: Conservador
#
#
# CPF: 47014057561
# Carteira de investimentos: (4600.0, 3600.0, 1000.0, 200.0)
# Perfil: Conservador
#
#
# CPF: 57183542047
# ...
